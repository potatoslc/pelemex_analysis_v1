# %%
#import gas_property_cantera
import pandas as pd
import numpy as np
import math
import cantera as ct
#pd.set_option("display.float_format", "{:.6f}".format)
#np.set_printoptions(suppress=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-830715526.py in <cell line: 0>()
#       3 import numpy as np
#       4 import math
# ----> 5 import cantera as ct
#       6 #pd.set_option("display.float_format", "{:.6f}".format)
#       7 #np.set_printoptions(suppress=True)
#
# ModuleNotFoundError: No module named 'cantera'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install cantera
# Out:
# Collecting cantera
#   Downloading cantera-3.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: numpy<3,>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from cantera) (2.0.2)
# Collecting ruamel.yaml>=0.15.34 (from cantera)
#   Downloading ruamel.yaml-0.18.15-py3-none-any.whl.metadata (25 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.15.34->cantera)
#   Downloading ruamel.yaml.clib-0.2.12-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Downloading cantera-3.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (19.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.0/19.0 MB 76.5 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.15-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 8.4 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.12-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (754 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 754.1/754.1 kB 38.1 MB/s eta 0:00:00
# Installing collected packages: ruamel.yaml.clib, ruamel.yaml, cantera
# Successfully installed cantera-3.1.0 ruamel.yaml-0.18.15 ruamel.yaml.clib-0.2.12

# %%
def get_property(fuel='H2',oxy_agent='air',ratio=1,temp=300,pressure=101325):
    oxy_comp = {'air':'O2:1, N2:3.76','O2':'O2:1'}

    gas = ct.Solution('gri30.yaml')
    gas.TP = temp,pressure
    gas.set_equivalence_ratio(ratio,fuel,oxy_comp[oxy_agent])

    return gas.density, gas.viscosity


def get_tau(velocity,density,re):

    return

def resolution_check_yplus(gridsize,fuel='H2',oxy='air',temp=300,ratio=1,pressure=101325,velocity=10,channel_height=1):
    density,viscosity = get_property(fuel,oxy,0.4,300,101325)
    re= velocity*channel_height*density/viscosity
    np.set_printoptions(suppress=True, precision=6)
    if re<0:
        return -1
    if re<1400:
        tau =0.5* 16/(3*re)*(velocity**2) *density
    else:
        tau = 0.5*0.073*(re**(-0.25))*(velocity**2) *density
    viscous_len = (viscosity/density/(math.sqrt(tau/density)))
    #print(viscous_len)
    y_plus_1 = gridsize/viscous_len
    #y_plus_10 = np.floor(10*gridsize/viscous_len
    #y_plus_1 = gridsize*(math.sqrt(tau/density))/viscosity
    #y_plus_10 = 10*gridsize*(math.sqrt(tau/density))/viscosity
    print(f'With given condition, viscous lengthscale is {viscous_len} m.')
    #print(f'The first grid point is located at y+ = {y_plus_1}.')
    #print(f'The 10th grid point is located at y+ = {y_plus_1}.')
    pts_1yp = np.floor(1*viscous_len/gridsize)
    pts_10yp = np.floor(10*viscous_len/gridsize)
    print(f'There will be {pts_1yp} points with in y+ = 1.')
    print(f'There will be {pts_10yp} points with in y+ = 10.')


    return viscous_len, pts_1yp,pts_10yp
    #return viscous_len, y_plus_1,y_plus_10

def resolution_check_gridsize(fuel='H2',oxy='air',temp=300,ratio=1,pressure=101325,velocity=10,channel_height=1):
    density,viscosity = get_property(fuel,oxy,ratio,300,101325)
    #print(f'density is {density}')
    print(f'viscosity is {viscosity}')
    re= velocity*channel_height*density/viscosity
    if re<0:
        return -1
    if re<1400:
        tau =0.5* 16/(3*re)*(velocity**2) *density
    else:
        tau = 0.5*0.073*(re**(-0.25))*(velocity**2) *density
    viscous_len = (viscosity/density/(math.sqrt(tau/density)))
    grid_yp1 = 1*viscous_len/1
    grid_yp10 = 10* viscous_len/13
    #print(f'The gridsize needs to have 1st grid point within y+ =1 is {grid_yp1} meter.')
    #print(f'The gridsize needs to have 13 grid points within y+ =10 is {grid_yp10} meter.')


    return viscous_len, grid_yp1,grid_yp10

# %%
#vl1,yp1,yp10 = resolution_check(0.000018,'H2','air',300,0.4,101325,12.5,0.02)
#vg1,yp1,yp10 =resolution_check_gridsize('H2','air',300,0.4,101325,12.5,0.02)

# %%
phi_list = np.linspace(0.1,1,10)
vel_list = np.linspace(5,15,21)
df_f = pd.DataFrame('0', index=phi_list, columns=vel_list)

# %%
for i in range(df_f.shape[0]):
    for j in range(df_f.shape[1]):
        _,typ1,typ10 = resolution_check_gridsize('H2','air',300,phi_list[i],101325,vel_list[j],0.02)
        print(f'The phi is {phi_list[i]} and the velocity is {vel_list[j]}.')
        #print(vel_list[j])
        df_f.iloc[i,j] = str(typ1)+'  ,  '+str(typ10)
# Out:
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 5.0.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 5.5.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 6.0.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 6.5.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 7.0.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 7.5.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 8.0.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 8.5.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 9.0.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 9.5.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 10.0.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 10.5.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 11.0.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 11.5.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 12.0.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 12.5.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 13.0.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 13.5.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 14.0.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 14.5.
# viscosity is 1.8614336130431555e-05
# The phi is 0.1 and the velocity is 15.0.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 5.0.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 5.5.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 6.0.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 6.5.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 7.0.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 7.5.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 8.0.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 8.5.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 9.0.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 9.5.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 10.0.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 10.5.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 11.0.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 11.5.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 12.0.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 12.5.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 13.0.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 13.5.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 14.0.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 14.5.
# viscosity is 1.859470615840139e-05
# The phi is 0.2 and the velocity is 15.0.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 5.0.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 5.5.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 6.0.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 6.5.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 7.0.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 7.5.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 8.0.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 8.5.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 9.0.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 9.5.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 10.0.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 10.5.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 11.0.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 11.5.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 12.0.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 12.5.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 13.0.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 13.5.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 14.0.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 14.5.
# viscosity is 1.8571874904917708e-05
# The phi is 0.30000000000000004 and the velocity is 15.0.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 5.0.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 5.5.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 6.0.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 6.5.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 7.0.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 7.5.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 8.0.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 8.5.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 9.0.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 9.5.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 10.0.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 10.5.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 11.0.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 11.5.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 12.0.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 12.5.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 13.0.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 13.5.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 14.0.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 14.5.
# viscosity is 1.8546167983723497e-05
# The phi is 0.4 and the velocity is 15.0.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 5.0.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 5.5.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 6.0.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 6.5.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 7.0.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 7.5.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 8.0.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 8.5.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 9.0.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 9.5.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 10.0.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 10.5.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 11.0.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 11.5.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 12.0.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 12.5.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 13.0.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 13.5.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 14.0.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 14.5.
# viscosity is 1.8517879447454438e-05
# The phi is 0.5 and the velocity is 15.0.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 5.0.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 5.5.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 6.0.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 6.5.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 7.0.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 7.5.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 8.0.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 8.5.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 9.0.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 9.5.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 10.0.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 10.5.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 11.0.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 11.5.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 12.0.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 12.5.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 13.0.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 13.5.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 14.0.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 14.5.
# viscosity is 1.8487275171491436e-05
# The phi is 0.6 and the velocity is 15.0.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 5.0.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 5.5.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 6.0.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 6.5.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 7.0.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 7.5.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 8.0.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 8.5.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 9.0.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 9.5.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 10.0.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 10.5.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 11.0.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 11.5.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 12.0.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 12.5.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 13.0.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 13.5.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 14.0.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 14.5.
# viscosity is 1.8454595829334147e-05
# The phi is 0.7000000000000001 and the velocity is 15.0.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 5.0.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 5.5.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 6.0.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 6.5.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 7.0.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 7.5.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 8.0.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 8.5.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 9.0.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 9.5.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 10.0.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 10.5.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 11.0.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 11.5.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 12.0.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 12.5.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 13.0.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 13.5.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 14.0.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 14.5.
# viscosity is 1.842005951473717e-05
# The phi is 0.8 and the velocity is 15.0.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 5.0.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 5.5.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 6.0.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 6.5.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 7.0.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 7.5.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 8.0.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 8.5.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 9.0.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 9.5.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 10.0.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 10.5.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 11.0.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 11.5.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 12.0.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 12.5.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 13.0.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 13.5.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 14.0.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 14.5.
# viscosity is 1.8383864057562587e-05
# The phi is 0.9 and the velocity is 15.0.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 5.0.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 5.5.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 6.0.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 6.5.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 7.0.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 7.5.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 8.0.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 8.5.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 9.0.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 9.5.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 10.0.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 10.5.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 11.0.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 11.5.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 12.0.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 12.5.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 13.0.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 13.5.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 14.0.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 14.5.
# viscosity is 1.8346189073380264e-05
# The phi is 1.0 and the velocity is 15.0.

# %%
df_f
# Out:
#                                                  5.0   \
# 0.1   5.131212948607203e-05  ,  3.947086883544002e-05
# 0.2  5.293346256662837e-05  ,  4.0718048128175665e-05
# 0.3  5.4526367418097404e-05  ,  4.194335955238261e-05
# 0.4   5.609150649105578e-05  ,  4.314731268542752e-05
# 0.5   5.762953531227591e-05  ,  4.433041177867378e-05
# 0.6  5.9141100621376006e-05  ,  4.549315432413539e-05
# 0.7  6.0626838883445306e-05  ,  4.663602991034254e-05
# 0.8  6.208737511832597e-05  ,  4.7759519321789214e-05
# 0.9   6.352332199609348e-05  ,  4.886409384314883e-05
# 1.0    6.493527915588974e-05  ,  4.99502147352998e-05
#
#                                                  5.5   \
# 0.1  4.7206460542416284e-05  ,  3.631266195570484e-05
# 0.2   4.869806490302213e-05  ,  3.746004992540164e-05
# 0.3  5.0163515679901464e-05  ,  3.858731975377035e-05
# 0.4   5.160342231856588e-05  ,  3.969494024505068e-05
# 0.5   5.301838789472141e-05  ,  4.078337530363185e-05
# 0.6   5.440900740001182e-05  ,  4.185308261539371e-05
# 0.7   5.577586637365409e-05  ,  4.290451259511854e-05
# 0.8   5.711953982539378e-05  ,  4.393810755799522e-05
# 0.9   5.844059140335912e-05  ,  4.495430107950701e-05
# 1.0  5.9739572767396966e-05  ,  4.595351751338228e-05
#
#                                                  6.0   \
# 0.1  4.3745808576900993e-05  ,  3.365062198223153e-05
# 0.2  4.512806511725111e-05  ,  3.4713896244039315e-05
# 0.3   4.648608536337042e-05  ,  3.575852720259263e-05
# 0.4   4.782043408301282e-05  ,  3.678494929462525e-05
